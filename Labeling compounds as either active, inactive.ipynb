# %% [markdown]
# ---

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
import pandas as pd  # Import the pandas library and give it the alias 'pd'

# %%
url = "https://raw.githubusercontent.com/az09tuan/PLK1/main/PLK-1-Pubchem-xChemBL.csv"

# %%
data=pd.read_csv(url)

# %%
bioactivity_class = []
for i in data.IC50:
    if float(i) >= 10000:
        bioactivity_class.append("inactive")
    elif float(i) <= 1000:
        bioactivity_class.append("active")
    else:
        bioactivity_class.append("intermediate")

# %%
bioactivity_class1 = pd.DataFrame({'bioactivity_class': bioactivity_class})
bioactivity_class1
# Out:
#      bioactivity_class
# 0               active
# 1               active
# 2               active
# 3               active
# 4               active
# ...                ...
# 3243          inactive
# 3244      intermediate
# 3245      intermediate
# 3246          inactive
# 3247      intermediate
#
# [3248 rows x 1 columns]

# %%
df = pd.concat([data, bioactivity_class1], axis=1)
df
# Out:
#                                                   SMILE       IC50   Source  \
# 0     CC[C@@H]1C(=O)N(C2=CN=C(N=C2N1C3CCCC3)NC4=C(C=...      0.083  Pubchem
# 1     CC[C@@H]1C2=C(N=CN2C3=CN=C(N=C3N1C(C)C)NC4=C(C...      0.400  Pubchem
# 2     CN(C)C1CCN(CC1)C2=CC(=C(C=C2)NC3=NC=C(C(=N3)NC...      0.508  Pubchem
# 3     CN1CCN(CC1)C2CCN(CC2)C3=CC=C(C=C3)NC4=NC=C(C(=...      0.508  Pubchem
# 4     CN(C)CC(=O)N1CCC2=CC(=C(C=C21)NC3=NC=C(C(=N3)N...      0.508  Pubchem
# ...                                                 ...        ...      ...
# 3243         CCCCCCCCSc1ccc(C(=O)Nc2ccc(C)cc2C(=O)O)cc1  26800.000   CHEMBL
# 3244  CC[C@@H]1C(=O)N(C)c2cnc(N(C)c3ccc(-c4nc5c(C(N)...   2028.000   CHEMBL
# 3245         CCCCCCCCc1ccc(C(=O)Nc2ccc(OC)cc2C(=O)O)cc1   5900.000   CHEMBL
# 3246  C[C@@]12CN(Cc3cccc(C#N)c3)C[C@@](C)(C1)c1c(-c3...  17900.000   CHEMBL
# 3247  Cc1ccccc1-n1c(=O)c2cnc(Nc3ccc(N4CCN(C)CC4)cc3)...   1800.000   CHEMBL
#
#      bioactivity_class
# 0               active
# ...

# %% [markdown]
# Saves dataframe to CSV file

# %%
df.to_csv('bioactivity_data_preprocessed-PLK1.csv', index=False)

# %% [markdown]
# ---
