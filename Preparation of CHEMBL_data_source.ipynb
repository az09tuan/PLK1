# %% [markdown]
# ## **ChEMBL Database**

# %% [markdown]
# ## **Installing libraries**

# %% [markdown]
# Install the ChEMBL web service package

# %%
! pip install chembl_webresource_client
# Out:
# Collecting chembl_webresource_client
#   Downloading chembl_webresource_client-0.10.9-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 788.6 kB/s eta 0:00:00
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (2.0.7)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (2.31.0)
# Collecting requests-cache~=1.2 (from chembl_webresource_client)
#   Downloading requests_cache-1.2.0-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 3.1 MB/s eta 0:00:00
# Requirement already satisfied: easydict in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (1.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2024.6.2)
# Requirement already satisfied: attrs>=21.2 in /usr/local/lib/python3.10/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (23.2.0)
# Collecting cattrs>=22.2 (from requests-cache~=1.2->chembl_webresource_client)
#   Downloading cattrs-23.2.3-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (4.2.2)
# Collecting url-normalize>=1.4 (from requests-cache~=1.2->chembl_webresource_client)
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Requirement already satisfied: exceptiongroup>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from cattrs>=22.2->requests-cache~=1.2->chembl_webresource_client) (1.2.1)
# Requirement already satisfied: typing-extensions!=4.6.3,>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from cattrs>=22.2->requests-cache~=1.2->chembl_webresource_client) (4.12.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from url-normalize>=1.4->requests-cache~=1.2->chembl_webresource_client) (1.16.0)
# Installing collected packages: url-normalize, cattrs, requests-cache, chembl_webresource_client
# Successfully installed cattrs-23.2.3 chembl_webresource_client-0.10.9 requests-cache-1.2.0 url-normalize-1.4.3

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for coronavirus**

# %%
# Target search for coronavirus
target = new_client.target
target_query = target.search('PLK1')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                     cross_references        organism  \
# 0  [{'xref_id': 'P70032', 'xref_name': None, 'xre...  Xenopus laevis
# 1  [{'xref_id': 'P53350', 'xref_name': None, 'xre...    Homo sapiens
# 2                                                 []    Homo sapiens
# 3                                                 []    Homo sapiens
#
#                                        pref_name  score  species_group_flag  \
# 0           Serine/threonine-protein kinase PLK1   28.0               False
# 1           Serine/threonine-protein kinase PLK1   18.0               False
# 2  Cereblon/Serine/threonine-protein kinase PLK1   18.0               False
# 3       Mitotic interactor and substrate of PLK1   15.0               False
#
#   target_chembl_id                                  target_components  \
# 0       CHEMBL4519  [{'accession': 'P70032', 'component_descriptio...
# 1       CHEMBL3024  [{'accession': 'P53350', 'component_descriptio...
# 2    CHEMBL4742280  [{'accession': 'P53350', 'component_descriptio...
# 3    CHEMBL4295893  [{'accession': 'Q8IVT2', 'component_descriptio...
#
#                    target_type  tax_id
# 0               SINGLE PROTEIN    8355
# 1               SINGLE PROTEIN    9606
# 2  PROTEIN-PROTEIN INTERACTION    9606
# 3               SINGLE PROTEIN    9606

# %% [markdown]
# Download the data from target_chembl_id: CHEMBL4519

# %%
t1= targets.target_chembl_id[1]

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id__in=(t1)).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df.head(3)
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None             None       750655                  []
# 1        None             None      1662506                  []
# 2        None             None      1662531                  []
#
#   assay_chembl_id                 assay_description assay_type  \
# 0    CHEMBL763908         Inhibition of PLK1 kinase          B
# 1    CHEMBL864552  Inhibitory activity against Plk1          B
# 2    CHEMBL864552  Inhibitory activity against Plk1          B
#
#   assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0                    None                   None  BAO_0000190  ...
# 1                    None                   None  BAO_0000190  ...
# 2                    None                   None  BAO_0000190  ...
#
#   target_organism                      target_pref_name target_tax_id  \
# 0    Homo sapiens  Serine/threonine-protein kinase PLK1          9606
# 1    Homo sapiens  Serine/threonine-protein kinase PLK1          9606
# 2    Homo sapiens  Serine/threonine-protein kinase PLK1          9606
#
#   text_value  toid  type units    uo_units upper_value    value
# 0       None  None  IC50    nM  UO_0000065        None  10000.0
# 1       None  None  IC50    uM  UO_0000065        None    100.0
# 2       None  None  IC50    uM  UO_0000065        None     20.0
#
# [3 rows x 46 columns]

# %%
df.to_csv('bioactivity_data_raw_IC50.csv', index=False)

# %% [markdown]
# ## **Handling missing data**
# Remove any compounds that have null/missing values in the "standard_value" column from the dataset. This ensures data completeness for IC50 analysis.

# %%
df2 = df[df.standard_value.notna()]
df2
# Out:
#                                             action_type activity_comment  \
# 0                                                  None             None
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# ...                                                 ...              ...
# 1569                                               None             None
# 1570                                               None             None
# 1571  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1572  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1573  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#       activity_id                                activity_properties  \
# 0          750655                                                 []
# 1         1662506                                                 []
# 2         1662531                                                 []
# 3         1662532                                                 []
# 4         1662533                                                 []
# ...           ...                                                ...
# 1569     25097347  [{'comments': None, 'relation': '=', 'result_f...
# 1570     25097348  [{'comments': None, 'relation': '=', 'result_f...
# 1571     25097349  [{'comments': None, 'relation': '=', 'result_f...
# 1572     25097350  [{'comments': None, 'relation': '=', 'result_f...
# 1573     25105837                                                 []
#
#      assay_chembl_id                                  assay_description  \
# 0       CHEMBL763908                          Inhibition of PLK1 kinase
# 1       CHEMBL864552                   Inhibitory activity against Plk1
# 2       CHEMBL864552                   Inhibitory activity against Plk1
# 3       CHEMBL864552                   Inhibitory activity against Plk1
# 4       CHEMBL864552                   Inhibitory activity against Plk1
# ...              ...                                                ...
# 1569   CHEMBL5260350  Inhibition of human N-terminal His6-tagged rec...
# 1570   CHEMBL5260350  Inhibition of human N-terminal His6-tagged rec...
# 1571   CHEMBL5260350  Inhibition of human N-terminal His6-tagged rec...
# 1572   CHEMBL5260350  Inhibition of human N-terminal His6-tagged rec...
# 1573   CHEMBL5263242  Inhibition of full-length His-tagged human PLK...
#
#      assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0             B                    None                   None  BAO_0000190
# 1             B                    None                   None  BAO_0000190
# 2             B                    None                   None  BAO_0000190
# 3             B                    None                   None  BAO_0000190
# 4             B                    None                   None  BAO_0000190
# ...         ...                     ...                    ...          ...
# 1569          B                    None                   None  BAO_0000190
# 1570          B                    None                   None  BAO_0000190
# 1571          B                    None                   None  BAO_0000190
# 1572          B                    None                   None  BAO_0000190
# 1573          B                    None                   None  BAO_0000190
#
#       ... target_organism                      target_pref_name target_tax_id  \
# 0     ...    Homo sapiens  Serine/threonine-protein kinase PLK1          9606
# 1     ...    Homo sapiens  Serine/threonine-protein kinase PLK1          9606
# 2     ...    Homo sapiens  Serine/threonine-protein kinase PLK1          9606
# 3     ...    Homo sapiens  Serine/threonine-protein kinase PLK1          9606
# 4     ...    Homo sapiens  Serine/threonine-protein kinase PLK1          9606
# ...   ...             ...                                   ...           ...
# 1569  ...    Homo sapiens  Serine/threonine-protein kinase PLK1          9606
# 1570  ...    Homo sapiens  Serine/threonine-protein kinase PLK1          9606
# 1571  ...    Homo sapiens  Serine/threonine-protein kinase PLK1          9606
# 1572  ...    Homo sapiens  Serine/threonine-protein kinase PLK1          9606
# 1573  ...    Homo sapiens  Serine/threonine-protein kinase PLK1          9606
#
#      text_value  toid  type units    uo_units upper_value    value
# 0          None  None  IC50    nM  UO_0000065        None  10000.0
# 1          None  None  IC50    uM  UO_0000065        None    100.0
# 2          None  None  IC50    uM  UO_0000065        None     20.0
# 3          None  None  IC50    uM  UO_0000065        None    100.0
# 4          None  None  IC50    uM  UO_0000065        None    100.0
# ...         ...   ...   ...   ...         ...         ...      ...
# 1569       None  None  IC50    nM  UO_0000065        None  25000.0
# 1570       None  None  IC50    nM  UO_0000065        None  25000.0
# 1571       None  None  IC50    nM  UO_0000065        None     16.0
# 1572       None  None  IC50    nM  UO_0000065        None      2.5
# 1573       None  None  IC50    nM  UO_0000065        None     19.0
#
# [1563 rows x 46 columns]

# %%
df2.to_csv('bioactivity_data_Potency2.csv', index=False)

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# # Labeling compounds as either being active, inactive or intermediate

# %% [markdown]
# ### **Combine the 3 columns (molecule_chembl_id,canonical_smiles,standard_value) and bioactivity_class into a DataFrame**

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2[selection]
df3
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL115220             O=C(Cc1ccc2ccccc2c1)Nc1cc(C2CC2)n[nH]1
# 1          CHEMBL200586                          COC(=O)c1cc2c(C)n[nH]c2s1
# 2          CHEMBL199996          Cc1n[nH]c2sc(C(N)=O)c(NC(=O)Nc3ccccc3)c12
# 3          CHEMBL199658       Cc1n[nH]c2sc(C(N)=O)c(NC(=O)c3ccc(Cl)cc3)c12
# 4          CHEMBL199657       Cc1n[nH]c2sc(C(N)=O)c(NC(=O)c3cccc(Cl)c3)c12
# ...                 ...                                                ...
# 1569      CHEMBL5266595  CCn1c(=O)c(-c2c(Cl)cccc2Cl)cc2cnc(Nc3ccc(N4CCN...
# 1570      CHEMBL5275152  C=CCn1c(=O)c2cnc(Nc3ccc4c(c3)CN(C)CC4)cc2n1-c1...
# 1571      CHEMBL5272327  C=CCn1c(=O)c2cnc(Nc3ccc(N4CCN(C)CC4)c4ccn(C)c3...
# 1572      CHEMBL1233528  CC[C@@H]1C(=O)N(C)c2cnc(Nc3ccc(C(=O)N[C@H]4CC[...
# 1573      CHEMBL5281562  CCn1c(=O)/c(=C/Nc2cccc(CCN3CCCC3)c2)s/c1=C(\C#...
#
#      standard_value
# 0           10000.0
# 1          100000.0
# 2           20000.0
# 3          100000.0
# 4          100000.0
# ...             ...
# 1569        25000.0
# 1570        25000.0
# 1571           16.0
# 1572            2.5
# 1573           19.0
#
# [1563 rows x 3 columns]

# %%
df3.to_csv('bioactivity_data_raw-PLK1-ChemBL.csv', index=False)

# %%
df3=pd.read_csv(r'bioactivity_data_raw-PLK1-ChemBL.csv')
df3
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL115220             O=C(Cc1ccc2ccccc2c1)Nc1cc(C2CC2)n[nH]1
# 1          CHEMBL200586                          COC(=O)c1cc2c(C)n[nH]c2s1
# 2          CHEMBL199996          Cc1n[nH]c2sc(C(N)=O)c(NC(=O)Nc3ccccc3)c12
# 3          CHEMBL199658       Cc1n[nH]c2sc(C(N)=O)c(NC(=O)c3ccc(Cl)cc3)c12
# 4          CHEMBL199657       Cc1n[nH]c2sc(C(N)=O)c(NC(=O)c3cccc(Cl)c3)c12
# ...                 ...                                                ...
# 1558      CHEMBL5266595  CCn1c(=O)c(-c2c(Cl)cccc2Cl)cc2cnc(Nc3ccc(N4CCN...
# 1559      CHEMBL5275152  C=CCn1c(=O)c2cnc(Nc3ccc4c(c3)CN(C)CC4)cc2n1-c1...
# 1560      CHEMBL5272327  C=CCn1c(=O)c2cnc(Nc3ccc(N4CCN(C)CC4)c4ccn(C)c3...
# 1561      CHEMBL1233528  CC[C@@H]1C(=O)N(C)c2cnc(Nc3ccc(C(=O)N[C@H]4CC[...
# 1562      CHEMBL5281562  CCn1c(=O)/c(=C/Nc2cccc(CCN3CCCC3)c2)s/c1=C(\C#...
#
#       standard_value
# 0            10000.0
# 1           100000.0
# 2            20000.0
# 3           100000.0
# 4           100000.0
# ...              ...
# 1558         25000.0
# 1559         25000.0
# 1560            16.0
# 1561             2.5
# 1562            19.0
#
# [1563 rows x 3 columns]

# %% [markdown]
# IC50 represents the concentration needed to inhibit 50% of a biological target's activity. Lower IC50 values indicate stronger binding/inhibition, hence compounds with IC50 < 1,000 nM are considered active since they can achieve significant inhibition at lower concentrations. Compounds requiring higher concentrations (>10,000 nM) are classified as inactive due to their weak binding affinity.

# %%
bioactivity_class = []
for i in df3.standard_value:
    if float(i) >= 10000:
        bioactivity_class.append("inactive")
    elif float(i) <= 1000:
        bioactivity_class.append("active")
    else:
        bioactivity_class.append("intermediate")

# %%
bioactivity_class1 = pd.DataFrame({'bioactivity_class': bioactivity_class})
bioactivity_class1.to_csv('bioactivityclass.csv', index=False)
bioactivity_class1
# Out:
#      bioactivity_class
# 0             inactive
# 1             inactive
# 2             inactive
# 3             inactive
# 4             inactive
# ...                ...
# 1558          inactive
# 1559          inactive
# 1560            active
# 1561            active
# 1562            active
#
# [1563 rows x 1 columns]

# %%
df4 = pd.concat([df3, bioactivity_class1], axis=1)
df4
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL115220             O=C(Cc1ccc2ccccc2c1)Nc1cc(C2CC2)n[nH]1
# 1          CHEMBL200586                          COC(=O)c1cc2c(C)n[nH]c2s1
# 2          CHEMBL199996          Cc1n[nH]c2sc(C(N)=O)c(NC(=O)Nc3ccccc3)c12
# 3          CHEMBL199658       Cc1n[nH]c2sc(C(N)=O)c(NC(=O)c3ccc(Cl)cc3)c12
# 4          CHEMBL199657       Cc1n[nH]c2sc(C(N)=O)c(NC(=O)c3cccc(Cl)c3)c12
# ...                 ...                                                ...
# 1558      CHEMBL5266595  CCn1c(=O)c(-c2c(Cl)cccc2Cl)cc2cnc(Nc3ccc(N4CCN...
# 1559      CHEMBL5275152  C=CCn1c(=O)c2cnc(Nc3ccc4c(c3)CN(C)CC4)cc2n1-c1...
# 1560      CHEMBL5272327  C=CCn1c(=O)c2cnc(Nc3ccc(N4CCN(C)CC4)c4ccn(C)c3...
# 1561      CHEMBL1233528  CC[C@@H]1C(=O)N(C)c2cnc(Nc3ccc(C(=O)N[C@H]4CC[...
# 1562      CHEMBL5281562  CCn1c(=O)/c(=C/Nc2cccc(CCN3CCCC3)c2)s/c1=C(\C#...
#
#       standard_value bioactivity_class
# 0            10000.0          inactive
# 1           100000.0          inactive
# 2            20000.0          inactive
# 3           100000.0          inactive
# 4           100000.0          inactive
# ...              ...               ...
# 1558         25000.0          inactive
# 1559         25000.0          inactive
# 1560            16.0            active
# 1561             2.5            active
# 1562            19.0            active
#
# [1563 rows x 4 columns]

# %% [markdown]
# Save the the processed data from ChemBL

# %%
df4.to_csv('bioactivity_data_preprocessed-PLK1.csv', index=False)

# %%
! ls -l
# Out:
# total 1400
# -rw-r--r-- 1 root root   6735 May 13 01:34 bioactivityclass.csv
# -rw-r--r-- 1 root root  87505 May 13 01:34 bioactivity_data_preprocessed.csv
# -rw-r--r-- 1 root root 602685 May 13 01:34 bioactivity_data_raw2.csv
# -rw-r--r-- 1 root root  80770 May 13 01:34 bioactivity_data_raw3.csv
# -rw-r--r-- 1 root root 639992 May 13 01:31 bioactivity_data_raw.csv
# drwxr-xr-x 1 root root   4096 May  9 13:24 sample_data

# %% [markdown]
# ---
